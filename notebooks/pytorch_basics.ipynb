# %%
import torch
x = torch.tensor([1,2,3])

print(x)
# Out:
# tensor([1, 2, 3])

# %%
print(x+1)
# Out:
# tensor([2, 3, 4])

# %%
matrix = torch.tensor([
    [1,2],
    [3,4]
])

print(matrix)
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
import torch.nn as nn

model = nn.Linear(2,1)

print(model)
# Out:
# Linear(in_features=2, out_features=1, bias=True)
