# %%
import matplotlib.pyplot as plt
attacks = ["A","B","C"]

success = [80,70,95]

plt.bar(attacks, success)

plt.title("Attack Success Rate")

plt.show()

# %%
epochs = [1,2,3,4,5]

accuracy = [50,60,70,85,92]

plt.plot(epochs,accuracy)

plt.xlabel("Epoch")

plt.ylabel("Accuracy")

plt.show()
