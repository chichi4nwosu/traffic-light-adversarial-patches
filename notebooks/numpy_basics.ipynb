# %%
import numpy as np
attack_rates = np.array([80,75,90,85])

print(attack_rates)
# Out:
# [80 75 90 85]

# %%
print(np.mean(attack_rates))
# Out:
# 82.5

# %%
print(np.max(attack_rates))
# Out:
# 90

# %%
print(np.max(attack_rates))
# Out:
# 90

# %%
import pandas as pd

# %%
data = {
    "Attack":["Patch A","Patch B","Patch C"],
    "Success Rate":[80,70,95]
}

df = pd.DataFrame(data)

df
# Out:
#     Attack  Success Rate
# 0  Patch A            80
# 1  Patch B            70
# 2  Patch C            95

# %%
df["Success Rate"].mean()
df.sort_values("Success Rate")
# Out:
#     Attack  Success Rate
# 1  Patch B            70
# 0  Patch A            80
# 2  Patch C            95
