# %%
print("Hello Chi-Chi")
# Out:
# Hello Chi-Chi

# %%
name = "Chi-Chi"
school = "UT Austin"

print(name)
print(school)
# Out:
# Chi-Chi
# UT Austin

# %%
research_interest = "Adversarial Attacks"

print("My research area is", research_interest)
# Out:
# My research area is Adversarial Attacks

# %%
x = 10
y = 5

print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 15
# 5
# 50
# 2.0

# %%
sensors = ["Camera","LiDAR","Radar","GPS"]

print(sensors)
# Out:
# ['Camera', 'LiDAR', 'Radar', 'GPS']

# %%
print(sensors[0])
print(sensors[2])
# Out:
# Camera
# Radar

# %%
def attack_success(rate):
    return rate > 70

print(attack_success(80))
# Out:
# True
